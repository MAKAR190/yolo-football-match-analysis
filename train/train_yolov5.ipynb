# %%
# !pip install roboflow
# !pip install python-dotenv

# %%
from dotenv import load_dotenv
from roboflow import Roboflow
import os
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
load_dotenv(dotenv_path="../.env.local")

api_key = os.getenv("ROBOFLOW_API_KEY")
workspace = os.getenv("ROBOFLOW_WORKSPACE")
project = os.getenv("ROBOFLOW_PROJECT")

# %%
rf = Roboflow(api_key)
project = rf.workspace(workspace).project(project)
version = project.version(1)
dataset = version.download("yolov5")

# %%
target_base = 'football-players-detection-1/football-players-detection-1'

os.makedirs(target_base, exist_ok=True)

for split in ["train", "test", "valid"]:
    src = f'football-players-detection-1/{split}'
    dst = f'{target_base}/{split}'
    os.rename(src, dst)

# %%
# !yolo task=detect model=yolov5xu.pt mode=train data={dataset.location}/data.yaml imgsz=512 batch=4 epochs=110 workers=2
